# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('weather.csv')
df
# Out:
#           date  precipitation  temp_max  temp_min  wind  weather
# 0     01-01-12            0.0      12.8       5.0   4.7  drizzle
# 1     02-01-12           10.9      10.6       2.8   4.5     rain
# 2     03-01-12            0.8      11.7       7.2   2.3     rain
# 3     04-01-12           20.3      12.2       5.6   4.7     rain
# 4     05-01-12            1.3       8.9       2.8   6.1     rain
# ...        ...            ...       ...       ...   ...      ...
# 1456  27-12-15            8.6       4.4       1.7   2.9     rain
# 1457  28-12-15            1.5       5.0       1.7   1.3     rain
# 1458  29-12-15            0.0       7.2       0.6   2.6      fog
# 1459  30-12-15            0.0       5.6      -1.0   3.4      sun
# 1460  31-12-15            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['weather']=lb.fit_transform(df['weather'])

# %%
df
# Out:
#           date  precipitation  temp_max  temp_min  wind  weather
# 0     01-01-12            0.0      12.8       5.0   4.7        0
# 1     02-01-12           10.9      10.6       2.8   4.5        2
# 2     03-01-12            0.8      11.7       7.2   2.3        2
# 3     04-01-12           20.3      12.2       5.6   4.7        2
# 4     05-01-12            1.3       8.9       2.8   6.1        2
# ...        ...            ...       ...       ...   ...      ...
# 1456  27-12-15            8.6       4.4       1.7   2.9        2
# 1457  28-12-15            1.5       5.0       1.7   1.3        2
# 1458  29-12-15            0.0       7.2       0.6   2.6        1
# 1459  30-12-15            0.0       5.6      -1.0   3.4        4
# 1460  31-12-15            0.0       5.6      -2.1   3.5        4
#
# [1461 rows x 6 columns]

# %%
df.describe()
# Out:
#        precipitation     temp_max     temp_min         wind      weather
# count    1461.000000  1461.000000  1461.000000  1461.000000  1461.000000
# mean        3.029432    16.439083     8.234771     3.241136     2.752225
# std         6.680194     7.349758     5.023004     1.437825     1.191380
# min         0.000000    -1.600000    -7.100000     0.400000     0.000000
# 25%         0.000000    10.600000     4.400000     2.200000     2.000000
# 50%         0.000000    15.600000     8.300000     3.000000     2.000000
# 75%         2.800000    22.200000    12.200000     4.000000     4.000000
# max        55.900000    35.600000    18.300000     9.500000     4.000000

# %%
df.columns
# Out:
# Index(['date', 'precipitation', 'temp_max', 'temp_min', 'wind', 'weather'], dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler
columns_to_scale=['precipitation', 'temp_max', 'temp_min', 'wind']
scaler=MinMaxScaler()
df[columns_to_scale]=scaler.fit_transform(df[columns_to_scale])

# %%
df.describe()
# Out:
#        precipitation     temp_max     temp_min         wind      weather
# count    1461.000000  1461.000000  1461.000000  1461.000000  1461.000000
# mean        0.054194     0.484922     0.603731     0.312213     2.752225
# std         0.119503     0.197574     0.197756     0.158003     1.191380
# min         0.000000     0.000000     0.000000     0.000000     0.000000
# 25%         0.000000     0.327957     0.452756     0.197802     2.000000
# 50%         0.000000     0.462366     0.606299     0.285714     2.000000
# 75%         0.050089     0.639785     0.759843     0.395604     4.000000
# max         1.000000     1.000000     1.000000     1.000000     4.000000

# %%
x=df.drop(['date','weather'],axis=1)
y=df['weather']

# %%
print(x)
print(y)
# Out:
#       precipitation  temp_max  temp_min      wind
# 0          0.000000  0.387097  0.476378  0.472527
# 1          0.194991  0.327957  0.389764  0.450549
# 2          0.014311  0.357527  0.562992  0.208791
# 3          0.363148  0.370968  0.500000  0.472527
# 4          0.023256  0.282258  0.389764  0.626374
# ...             ...       ...       ...       ...
# 1456       0.153846  0.161290  0.346457  0.274725
# 1457       0.026834  0.177419  0.346457  0.098901
# 1458       0.000000  0.236559  0.303150  0.241758
# 1459       0.000000  0.193548  0.240157  0.329670
# 1460       0.000000  0.193548  0.196850  0.340659
#
# [1461 rows x 4 columns]
# 0       0
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 1456    2
# 1457    2
# 1458    1
# 1459    4
# 1460    4
# Name: weather, Length: 1461, dtype: int64

# %%
from sklearn.naive_bayes import MultinomialNB, BernoulliNB

# %%
clf=BernoulliNB()

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k_folds = 5
kf = KFold(n_splits=k_folds, shuffle=True, random_state=42)
scores = cross_val_score(best_model, x, y, cv=kf, scoring='accuracy')

print("Cross-validation scores:", scores)
print("Mean score:", scores.mean())
# Out:
# Cross-validation scores: [0.82935154 0.8630137  0.84246575 0.83219178 0.86643836]
# Mean score: 0.8466922249754546

# %%
from sklearn.model_selection import GridSearchCV

parameters = {
    'alpha':[x/100 for x in range(100,200,1)],
    'binarize':[x for x in range(0,2)]
 }
grid_search = GridSearchCV(clf, parameters, n_jobs=-1,cv=5,scoring='accuracy')
grid_search.fit(x, y)

best_model = grid_search.best_estimator_

# %%
print(best_model)
# Out:
# BernoulliNB(binarize=0)
